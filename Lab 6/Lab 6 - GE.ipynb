# %% [markdown]
# # GTECH 731-Lab 6
# ## Griztko Erickson

# %% [markdown]
# ## Loading in Required Packages

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Data in GeoDataFrame

# %%
NYBears=gpd.read_file(r"C:\Users\grizt\Documents\GTECH785\NY Bears\AAA_Bears\Bears\American_Black_Bear_Range_in_NY.shp")
NABears=gpd.read_file(r"C:\Users\grizt\Documents\GTECH785\NY Bears\AAA_Bears\Bears\American_Black_Bear_Range_in_North_America.shp")
UTM18_Bears=gpd.read_file(r"C:\Users\grizt\Documents\GTECH785\NY Bears\AAA_Bears\Bears\NY_Black_Bear_Range_UTM18.shp")

# %% [markdown]
# ## Using .head() to Display Tabular Data, Nicely
# There's only two rows, so we don't specify anything inside the parenthesis

# %%
NABears.head(7)
# Out:
#    OBJECTID           Country  Status                 Label    Kilometers  \
# 0         1            Canada       1    Primary Bear Range  6.121051e+06
# 1         2            Canada       2  Secondary Bear Range  7.137482e+05
# 2         3      USA - Alaska       1    Primary Bear Range  9.174863e+05
# 3         4      USA - Alaska       2  Secondary Bear Range  1.600575e+02
# 4         5  USA - contiguous       1    Primary Bear Range  1.974933e+06
# 5         6  USA - contiguous       2  Secondary Bear Range  6.211212e+05
# 6         7            Mexico       1    Primary Bear Range  9.868283e+04
#
#          Miles last_edite                                           geometry
# 0  2363351.392       None  MULTIPOLYGON (((-136.51202 67.78489, -136.5209...
# 1   275579.758       None  MULTIPOLYGON (((-115.07441 65.57966, -115.0156...
# 2   354243.486       None  MULTIPOLYGON (((-160.69321 67.86298, -160.6060...
# ...

# %% [markdown]
# ## Displaying Data Types

# %%
type(NABears)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
for field in NABears:
    print(type(NABears[field][0]))
# Out:
# <class 'numpy.int64'>
# <class 'str'>
# <class 'numpy.int64'>
# <class 'str'>
# <class 'numpy.float64'>
# <class 'numpy.float64'>
# <class 'NoneType'>
# <class 'shapely.geometry.multipolygon.MultiPolygon'>

# %%
NABears.dtypes
# Out:
# OBJECTID         int64
# Country         object
# Status           int64
# Label           object
# Kilometers     float64
# Miles          float64
# last_edite      object
# geometry      geometry
# dtype: object

# %% [markdown]
# ## Whole and Individual Geometry

# %%
NABears.geometry.dtypes

# %%
type(NABears.geometry[0])
# Out:
# shapely.geometry.multipolygon.MultiPolygon

# %% [markdown]
# ## Exporting to Geopackage

# %%
NYBears.to_file("BlackBears.gpkg", layer="NYBears", driver="GPKG")
NABears.to_file("BlackBears.gpkg", layer="NABears", driver="GPKG")
UTM18_Bears.to_file("BlackBears.gpkg", layer="UTM18_Bears", driver="GPKG")

# %% [markdown]
# ## Visualizing The Data

# %%
NABears.plot(column="Country",legend=True)
# Out:
# <AxesSubplot: >
